# %% [markdown]
# # Imports and Reading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from gitly.colab.plot import GitlyPlotter
gitly = GitlyPlotter('github')
pd.set_option('display.max_columns', 200)
# Out:
# This script was made to run only on Google Colab notebooks, other environments was not tested completely
# You are not in Colab envirement, make sure you already have Plotly > 4.9.0 and kaleido

# %%
df = pd.read_csv('Speed_Dating_Data.csv', encoding = 'latin1')

# %% [markdown]
# Let's start by exploring the dataset.

# %%
print(f'Number of rows: {df.shape[0]}\n')
print(f'Number of columns: {df.shape[1]}\n')
print(f"Number of participants: {len(df['iid'].unique())} \n")
print('Display of dataset:')
display(df.head())
print('Percentage of missing values:')
display(df.isnull().sum() * 100 / len(df))
# Out:
# Number of rows: 8378
#
# Number of columns: 195
#
# Number of participants: 551
#
# Display of dataset:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order
# 0    1  1.0       0    1       1     1     10         7       NaN      4  \
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0  \
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
# ...

# %% [markdown]
# Let's see how many people got a match.

# %%
match = df["match"].value_counts() * 100 / len(df)
ax = sns.barplot(data=match, x=match.index, y=match.values)
ax.set(xlabel='Match', ylabel='Percentage', title='Percentage of Matches')
ax.set_xticklabels(["Yes", "No"])
plt.show()

# %% [markdown]
# Only 16% of people managed to get a second date !

# %% [markdown]
# ## We will now try to see why people agree to a second date.

# %% [markdown]
# ### What are the least desirable attributes in a male partner? Does this differ for female partners?

# %% [markdown]
# For the gender, 0 is for female, 1 for male

# %% [markdown]
# The following columns: 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1', represent what the person is looking for in the opposite sex. Let's rename the columns.

# %%
attributes_to_rename = {'attr1_1': 'Attractive', 'sinc1_1': 'Sincere',
                        'intel1_1': 'Intelligent', 'fun1_1': 'Fun',
                        'amb1_1': 'Ambitious', 'shar1_1': 'Interest'}

df = df.rename(columns=attributes_to_rename)

attributes = df[['gender', 'Attractive', 'Sincere', 'Intelligent', 'Fun', 'Ambitious', 'Interest']]

attributes = attributes.drop_duplicates()
attributes.head()
# Out:
#     gender  Attractive  Sincere  Intelligent   Fun  Ambitious  Interest
# 0        0        15.0     20.0         20.0  15.0       15.0      15.0
# 10       0        45.0      5.0         25.0  20.0        0.0       5.0
# 20       0        35.0     10.0         35.0  10.0       10.0       0.0
# 30       0        20.0     20.0         20.0  20.0       10.0      10.0
# 40       0        20.0      5.0         25.0  25.0       10.0      15.0

# %%
attributes_by_gender = attributes.groupby((['gender'])).mean()
attributes_by_gender
# Out:
#         Attractive    Sincere  Intelligent        Fun  Ambitious   Interest
# gender
# 0        18.172043  18.033191    21.200936  17.465872  12.634851  12.525513
# 1        27.307529  16.291725    19.319765  17.411929   8.810040  11.316838

# %%
female_values = attributes_by_gender.loc[0].tolist()
male_values = attributes_by_gender.loc[1].tolist()

# %% [markdown]
# Let's visualize it with Plotly.

# %%
fig = go.Figure()

trace_female = go.Scatterpolar(
    r=female_values,
    theta=attributes_by_gender.columns,
    fill='toself',
    name='Female'
)

trace_male = go.Scatterpolar(
    r=male_values,
    theta=attributes_by_gender.columns,
    fill='toself',
    name='Male'
)

layout = go.Layout(
    polar=dict(
        radialaxis=dict(visible=False),
    ),
    showlegend=True
)

data = [trace_female, trace_male]
fig = go.Figure(data=data, layout=layout)

gitly.show(fig)

# %% [markdown]
# We can observe that the preferences of male and female participants differ in terms of the importance they place on certain attributes:
#
# We can see that for male participants, the higher mean value for the 'attractive' attribute suggests that male participants prioritize the physical attractiveness of their partner.
#
# On the other hand, the higher mean value for the 'intelligent' attribute in the female group suggests that female participants value intelligence in their partner more than the other attributes.

# %% [markdown]
# ### How important do people think attractiveness is in potential mate selection vs. its real impact?

# %% [markdown]
# ### How important is it to have a shared racial background?

# %% [markdown]
# Let's see the distribution of all the races.

# %%
races_dict = {  1: 'Black/African American',
                2: "European/Caucasian-American",
                3: "Latino/Hispanic American",
                4: "Asian/Pacific Islander/Asian-American",
                5: "Native American",
                6: "Other"
               }
df['race'] = df['race'].replace(races_dict)
races = df["race"].value_counts()
fig = px.pie(values=races.values, names=races.index, title= "Distribution of the races")
gitly.show(fig)

# %% [markdown]
# More than half the number of participants are European/Caucasian-American, followed by Asian/Pacific Islander/Asian-American with almost 24%.

# %% [markdown]
# Let's now see how important it is for people to be from the same racial/ethnic background.

# %%
imprace_df = df["imprace"].value_counts(normalize=True).reset_index()
imprace_df
fig = px.bar(imprace_df, x="imprace", y="proportion", title= "Proportion of importance racial background")
fig.update_layout(yaxis_tickformat="0%")
gitly.show(fig)

# %% [markdown]
# More than half of the people don't really care if their partner is from the same racial backgound. A quarter think it's bit important and for the last quarter it has its importance.

# %% [markdown]
# ### How does the correlation between participant’s and partner’s ratings of interests at the beginning impact the actual result of the date ?

# %%
fig = px.scatter(df, x='int_corr', y='match',
                 color='match', 
                 labels={'int_corr': 'Correlation of Interests', 'match': 'Match'},
                 title='Correlation of Interests vs Match Outcome')

gitly.show(fig)

# %% [markdown]
# We can see that there are no actual impact to get a match.

# %% [markdown]
# ### In terms of getting a second date, is it better to be someone's first speed date of the night or their last?

# %%
speed_date = df.groupby("order")["match"]
speed_date_count = speed_date.count()
fig = px.bar(x=speed_date_count.index, y=speed_date_count.values, title= "Number of speed dates for each round")
gitly.show(fig)

# %% [markdown]
# We will drop the round 21 and 22 as there are less values.

# %%
speed_date_importance = speed_date.mean().reset_index(drop=True).iloc[:-1]
fig = px.bar(x=speed_date_importance.index, y=speed_date_importance.values, title= "Importance between the speed date's order")
gitly.show(fig)

# %% [markdown]
# We can see it is much better to be someone's first date than to be the last one.

# %% [markdown]
# ### What is the final conclusion ?

# %%
correlations = df[["match", 'order', 'int_corr', 'samerace', 'race_o', 'attr_o', 'imprace', 'imprelig', 'Attractive',
    'Sincere', 'Intelligent', 'Fun', 'Ambitious', 'Interest']]
f, ax = plt.subplots(figsize=(18, 10))
ax = sns.heatmap(correlations.corr(), annot=True)

# %% [markdown]
# attr_o is the rating by the partner on the night of the event, for all 6 attributes. It means if your partner gave you a high rating, it will more likely lead to getting a second date.
